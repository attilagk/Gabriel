# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import statsmodels as sm
import seaborn as sns
import re
from io import StringIO
import attila_utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Preparation

# %%
def subject_names(Control=6, ChAc=4):
    control = ['Control ' + str(i) for i in np.arange(1, Control + 1, 1, dtype=np.int64)]
    chac = ['ChAc ' + str(i) for i in np.arange(1, ChAc + 1, 1, dtype=np.int64)]
    val = control + chac
    return(val)

def reorder_columns(data):
    df = data.transpose()
    subject_cagegories = subject_names()
    df['subject'] = pd.Categorical(df.index.get_level_values(0), categories=subject_cagegories, ordered=True)
    df['region'] = pd.Categorical(df.index.get_level_values(1), categories=['CN', 'Putamen', 'DLPFC'], ordered=True)
    cols2drop = ['region', 'subject'] if isinstance(df.columns[0], str) else [('region', ), ('subject', )]
    df = df.sort_values([('region'), ('subject')]).drop(cols2drop, axis=1).transpose()
    return(df)

# %%
fpath = '../../resources/lipid-data-groups.csv'
group_levels = pd.read_csv(fpath, header=[0, 1], index_col=0).rename_axis(['Dx', 'Region'], axis=1).rename_axis('Group', axis=0)
group_levels = reorder_columns(group_levels)
group_levels
# Out:
# Dx     Control 1 Control 2 Control 3 Control 4 Control 5 Control 6    ChAc 1  \
# Region        CN        CN        CN        CN        CN        CN        CN
# Group
# FC      86.01249  78.49208  86.98186  73.47960  72.05994  70.35621  74.76526
# CE       0.59214   2.51143   0.94935   1.30370   3.70715   1.51144   3.11056
# AC       0.04726   0.08522   0.50852   0.05923   0.17098   0.05078   0.21767
# MG       0.02171   0.03618   0.02604   0.02827   0.03219   0.02505   0.06494
# DG       0.93269   0.64312   0.54213   0.43478   0.60878   0.44212   0.61273
# TG       0.00693   0.00652   0.01647   0.01522   0.03090   0.00921   0.03392
# Cer      0.41626   0.57438   0.42725   0.31078   0.54858   0.32819   0.47781
# dhCer    0.01023   0.01531   0.01231   0.01335   0.01526   0.00823   0.01206
# SM       0.17904   0.33050   0.26967   0.28869   0.40059   0.18089   0.35754
# dhSM     4.41459   7.06164   4.81671  13.65469  12.85972  13.14329  11.57979
# MhCer    0.39068   0.18478   0.21930   0.13245   0.13860   0.10065   0.21965
# Sulf     0.15741   0.08069   0.10720   0.06636   0.08390   0.06290   0.10959
# LacCer   0.56075   0.97227   0.30695   3.73009   1.68457   9.12296   0.89056
# GM3      0.00041   0.00280   0.00056   0.00059   0.00081   0.00040   0.00123
# GB3      0.00008   0.00043   0.00020   0.00152   0.00166   0.00406   0.00312
# PA       0.07772   0.08483   0.07913   0.22056   0.39788   0.36080   0.07850
# PC       0.52107   1.05357   0.70647   0.93283   1.24858   0.65105   1.22431
# PCe      0.08089   0.10000   0.10450   0.08023   0.09788   0.05547   0.14899
# PE       0.51837   2.12333   0.63283   1.45318   1.68540   0.77625   1.30639
# PEp      1.82470   2.99070   1.57652   1.82538   1.65885   0.88364   1.91448
# PS       1.49087   1.37922   0.77434   0.99727   1.21796   0.70540   1.46338
# PI       0.05898   0.15757   0.09251   0.11327   0.16364   0.07760   0.10503
# PG       0.00492   0.04293   0.02918   0.10122   0.15832   0.15292   0.02973
# BMP      0.04577   0.03038   0.05461   0.03317   0.02296   0.02777   0.09163
# AcylPG   0.00693   0.00089   0.00074   0.00072   0.00077   0.00124   0.00058
# LPC      0.12059   0.17787   0.15499   0.11957   0.23200   0.10410   0.13089
# LPCe     0.00322   0.00346   0.00250   0.00266   0.00400   0.00241   0.00281
g, ix = np.unique(ix0, return_index=True)
s = pd.Series(ix, index=g).sort_values() - 0.5
s1 = pd.Series(s.to_list() + [len(species_levels)], index=['start'] + s.index.to_list())
s1 = s1.rolling(window=2).mean().drop('start')
ticks = pd.concat([s.to_frame('tick_loc'), s1.to_frame('label_loc')], axis=1)
group_info = pd.DataFrame({'ticks': ix}, index=g).sort_values('ticks')
# Reorder columns to group Control and ChAc subjects together
c0 = subject_names()
c1 = ['CN', 'Putamen', 'DLPFC']
species_levels = species_levels.reindex(columns=pd.MultiIndex.from_product([c0, c1])).rename_axis(['Dx', 'Region'], axis=1).rename_axis(['Group', 'Species'], axis=0)
species_levels = reorder_columns(species_levels)
species_levels.to_csv('../../resources/lipid-data-species-pretty.csv')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: PerformanceWarning: indexing past lexsort depth may impact performance.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# For the submitted manuscript the old `normalize_v1` was used, which---incorrectly---normalizes each column (sample) separately across all lipid species.  For the revision `normalize` is used, which---correctly---normalizes each row (lipid species) across all samples.

# %%
# This standardizes each row (accross samples)
def standardize(data):
    val = data.apply(lambda x: (x - x.mean()) / x.std(), axis=1).fillna(0)
    return(val)

# New version (v2)
# This normalizes each row (accross samples)
def normalize(data):
    val = data.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1).fillna(0.5)
    return(val)

# Old version (v1)
# This normalizes each column (accross lipid species)
def normalize_v1(data):
    Min = data.min(axis=1)
    Max = data.max(axis=1)
    val = data.apply(lambda x: (x - Min) / (Max - Min), axis=0)
    return(val)


standardize(species_levels).to_csv('../../resources/lipid-data-species-standardized-pretty.csv')
normalize(species_levels).to_csv('../../resources/lipid-data-species-normalized-pretty.csv')

# %% [markdown]
# ## v2 heatmaps (new)

# %%
def make_colors_Region(data, cmap={'CN': 'C1', 'Putamen': 'gold', 'DLPFC': 'C0'}):
    df = data.columns.to_frame()
    val = df.Region.apply(lambda x: cmap[x]).to_list()
    cmap = pd.Series(cmap.values(), index=cmap.keys())
    return((val, cmap))

def make_colors_Dx(data, cmap={'Control': 'gray', 'ChAc': 'black'}):
    df = data.columns.to_frame()
    val = df.Dx.str.replace(' [0-9]$', '').apply(lambda x: cmap[x]).to_list()
    cmap = pd.Series(cmap.values(), index=cmap.keys())
    return((val, cmap))

def make_colors_Group(data, min_saturation=0.15):
    t = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))), name) for name, color in mcolors.CSS4_COLORS.items())
    t = (x for x in t if x[0][1] >= min_saturation)
    colors = list(x[1] for x in t)
    df = data.index.to_frame()
    groups = df.groupby(axis=0, level='Group', sort=False).first().index
    #groups = np.unique(df.Group)
    cmap = pd.Series(colors[:: -np.int16(np.floor(len(colors) / len(groups)))][:len(groups)], index=groups)
    #return(cmap)
    val = df.Group.apply(lambda x: cmap[x]).to_list()
    return((val, cmap))

def my_legend(g, cmap, title='Lipid group', loc='center left', bbox_to_anchor=(-0.3, 0.25, 0.5, 0.5), ncol=1):
    colors = cmap.to_list()
    handles = [mpatches.Patch(color=c) for c in colors]
    labels = cmap.index
    g.legend(handles, labels, title=title, loc=loc, bbox_to_anchor=bbox_to_anchor, ncol=ncol, prop={'family': 'monospace'})
    return(g)

def cmap_group_fullname(cmap, data, group_dict=pd.read_csv('../../resources/lipid-group-dictionary.csv', index_col='abbreviation')):
    df = pd.concat([cmap, pd.Series(group_dict.index, index=group_dict.index), group_dict, data.index.get_level_values(0).value_counts()], axis=1)
    s = StringIO()
    print(df[['name', 'Group']], file=s)
    ix = s.getvalue().split('\n')[1:-1]
    newcmap = cmap.copy()
    newcmap.index = ix
    return(newcmap)

# %%
def my_clustermap(species_levels, transform=standardize, row_cluster=False, col_cluster=False):
    data = transform(reorder_columns(species_levels))
    vmin = -3 if transform == standardize else 0
    vmax = 3 if transform == standardize else 1
    cmap = 'bwr' if transform == standardize else 'viridis'
    col_colors = [make_colors_Region(data)[0], make_colors_Dx(data)[0]]
    cmap_Region, cmap_Dx = [make_colors_Region(data)[1], make_colors_Dx(data)[1]]
    row_colors, cmap_group = make_colors_Group(data)
    g = sns.clustermap(data, cmap=cmap, vmin=vmin, vmax=vmax, row_cluster=row_cluster, col_cluster=col_cluster, row_colors=row_colors, col_colors=col_colors, cbar_pos=(0.75, 0.35, 0.05, 0.3), figsize=(9, 12))
    my_legend(g.fig, cmap_group_fullname(cmap_group, data), title='Lipid group (abbrev., full name, #lipid species)', loc='center left', bbox_to_anchor=(-0.45 - (0.1 if col_cluster else 0), 0.2, 0.5, 0.5), ncol=1)
    my_legend(g.fig, cmap_Region, title='Region', loc='lower center', bbox_to_anchor=(0.2, 0.875 + (0.1 if col_cluster else 0), 0.5, 0.1), ncol=3)
    my_legend(g.fig, cmap_Dx, title='Dx', loc='lower center', bbox_to_anchor=(0.2, 0.825 + (0.1 if col_cluster else 0), 0.5, 0.1), ncol=2)
    #g.ax_heatmap.set_xlabel('')
    g.ax_heatmap.set_ylabel('')
    g.ax_heatmap.set_yticks([])
    transformed = 'Standardized' if transform == standardize else 'Normalized'
    g.ax_cbar.set_ylabel(transformed + ' lipid level')
    return(g)

g = my_clustermap(species_levels)
attila_utils.savefig(g.fig, 'heatmap-std')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (await self.run_code(code, result,  async_=asy)):
# <ipython-input-6-e3adc37d4fbd>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   val = df.Dx.str.replace(' [0-9]$', '').apply(lambda x: cmap[x]).to_list()
# ['named-figure/heatmap-std.png', 'named-figure/heatmap-std.pdf']

# %%
g = my_clustermap(species_levels, transform=normalize)
attila_utils.savefig(g.fig, 'heatmap-norm')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (await self.run_code(code, result,  async_=asy)):
# <ipython-input-6-e3adc37d4fbd>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   val = df.Dx.str.replace(' [0-9]$', '').apply(lambda x: cmap[x]).to_list()
# ['named-figure/heatmap-norm.png', 'named-figure/heatmap-norm.pdf']

# %%
g = my_clustermap(species_levels, row_cluster=True, col_cluster=True)
attila_utils.savefig(g.fig, 'clustermap-std')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (await self.run_code(code, result,  async_=asy)):
# <ipython-input-6-e3adc37d4fbd>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   val = df.Dx.str.replace(' [0-9]$', '').apply(lambda x: cmap[x]).to_list()
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# ['named-figure/clustermap-std.png', 'named-figure/clustermap-std.pdf']

# %%
g = my_clustermap(species_levels, transform=normalize, row_cluster=True, col_cluster=True)
attila_utils.savefig(g.fig, 'clustermap-norm')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (await self.run_code(code, result,  async_=asy)):
# <ipython-input-6-e3adc37d4fbd>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   val = df.Dx.str.replace(' [0-9]$', '').apply(lambda x: cmap[x]).to_list()
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# ['named-figure/clustermap-norm.png', 'named-figure/clustermap-norm.pdf']

# %% [markdown]
# ## v1 heatmaps (old)

# %%
def single_panel_heatmap_ax(ax, region='CN', draw_yticklabels=True, draw_colorbar=False,
                            data=normalize_v1(species_levels), ticks=ticks, cmap='viridis', gridcolor='pink'):
    ax.imshow(data.xs(region, axis=1, level=1), aspect='auto', cmap=cmap, interpolation='none')
    #ax.set_yticks(ticks['tick_loc'])
    ax.set_yticks(ticks.loc['AC':, 'tick_loc'])
    ax.set_yticklabels('')
    ax.set_yticks(ticks['label_loc'], minor=True)
    if draw_yticklabels:
        ax.set_yticklabels(ticks.index, minor=True)
    ax.tick_params(axis='y', which='minor', length=0)
    ax.tick_params(axis='y', which='major', length=10)
    ax.tick_params(axis='x', which='major', length=0)
    ax.set_xticks(range(len(c0)))
    ax.set_xticklabels(data.xs(region, axis=1, level=1).columns, rotation=90)
    ax.grid(True, which='major', axis='y', color=gridcolor)
    ax.set_title(region, fontsize=14)
    if draw_colorbar:
        cm = plt.cm.ScalarMappable(cmap=cmap)
        cm.set_clim(vmin=0, vmax=1)
        cb_ax = fig.add_axes([0.92, 0.4, 0.02, 0.2])
        fig.colorbar(cm, cax=cb_ax, label='normalized lipid level')
    return((fig, ax))

fig, ax = plt.subplots(1, 3, figsize=(12, 12))
single_panel_heatmap_ax(ax[0], region='CN', draw_yticklabels=True, draw_colorbar=False)
single_panel_heatmap_ax(ax[1], region='Putamen', draw_yticklabels=True, draw_colorbar=False)
single_panel_heatmap_ax(ax[2], region='DLPFC', draw_yticklabels=True, draw_colorbar=True)
attila_utils.savefig(fig, 'single-panel-heatmap')
# Out:
# ['named-figure/single-panel-heatmap.png',
#  'named-figure/single-panel-heatmap.pdf']

# %%
def single_panel_heatmap(region='CN', data=normalize(species_levels), ticks=ticks, cmap='viridis', gridcolor='pink'):
    fig, ax = plt.subplots(figsize=(6, 15))
    ax.imshow(data.xs(region, axis=1, level=1), aspect='auto', cmap=cmap, interpolation='none')
    ax.set_yticks(ticks['tick_loc'])
    ax.set_yticklabels('')
    ax.set_yticks(ticks['label_loc'], minor=True)
    ax.set_yticklabels(ticks.index, minor=True)
    ax.tick_params(axis='y', which='minor', length=0)
    ax.tick_params(axis='y', which='major', length=10)
    ax.tick_params(axis='x', which='major', length=0)
    ax.set_xticks(range(len(c0)))
    ax.set_xticklabels(data.xs(region, axis=1, level=1).columns, rotation=90)
    ax.grid(True, which='major', axis='y', color=gridcolor)
    fig.suptitle('Lipid species in the ' + region, y=0.9)
    cm = plt.cm.ScalarMappable(cmap=cmap)
    cm.set_clim(vmin=0, vmax=1)
    cb_ax = fig.add_axes([0.92, 0.4, 0.02, 0.2])
    fig.colorbar(cm, cax=cb_ax, label='normalized lipid level')
    return((fig, ax))

fig, ax = single_panel_heatmap()
attila_utils.savefig(fig, 'single-panel-heatmap-CN')
# Out:
# ['named-figure/single-panel-heatmap-CN.png',
#  'named-figure/single-panel-heatmap-CN.pdf']

# %%
fig, ax = single_panel_heatmap(region='Putamen')
attila_utils.savefig(fig, 'single-panel-heatmap-Putamen')
# Out:
# ['named-figure/single-panel-heatmap-Putamen.png',
#  'named-figure/single-panel-heatmap-Putamen.pdf']

# %%
fig, ax = single_panel_heatmap(region='DLPFC')
attila_utils.savefig(fig, 'single-panel-heatmap-DLPFC')
# Out:
# ['named-figure/single-panel-heatmap-DLPFC.png',
#  'named-figure/single-panel-heatmap-DLPFC.pdf']

# %%
# %connect_info
# Out:
# {
#   "shell_port": 50793,
#   "iopub_port": 50794,
#   "stdin_port": 50795,
#   "control_port": 50797,
#   "hb_port": 50796,
#   "ip": "127.0.0.1",
#   "key": "1f990d5b-0d388bf5f0752e5619cba605",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-c3035050-3f2f-46f3-b481-2c75a62399bc.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
